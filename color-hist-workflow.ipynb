# %% [markdown]
# ## Get list of paths to images for a given source path

# %%
in_path = "examples/"

# %%
from colorstats.image_paths import rel_paths

img_paths = rel_paths(in_path)

# %% [markdown]
# ## Get Principle Components of color histograms from list of image paths

# %%
from colorstats.HSVHists import *

# %%
df = HSV_hist(img_paths, hue_bins=180, sat_bins=256, val_bins=256) #note OpenCV computes 180 bins for Hue histogram
df.head()
# Out:
#                                          image_paths      Hue0      Hue1  \
# 0  examples/Rothko_images/AMICO_BOSTON_103832163.jpg  0.002726  0.002063
# 1      examples/Rothko_images/AMICO_CL_103800789.jpg  0.000000  0.000006
# 2  examples/Rothko_images/AMICO_DALLAS_103842196.jpg  0.006887  0.006206
# 3  examples/Rothko_images/AMICO_DALLAS_103842510.jpg  0.351448  0.112515
# 4  examples/Rothko_images/AMICO_DALLAS_103842720.jpg  0.000000  0.000000
#
#        Hue2      Hue3      Hue4      Hue5      Hue6      Hue7      Hue8  \
# 0  0.004462  0.011715  0.020938  0.035809  0.060882  0.061984  0.065942
# 1  0.000006  0.000000  0.000006  0.000000  0.000000  0.000025  0.000019
# 2  0.013941  0.026225  0.031931  0.030116  0.032328  0.031266  0.026391
# 3  0.088669  0.060580  0.040318  0.025191  0.016142  0.012116  0.010075
# 4  0.000000  0.000000  0.000000  0.000000  0.000028  0.000000  0.000000
#
#      ...       Val246    Val247    Val248    Val249    Val250    Val251  \
# ...

# %%
df = HSV_hist(img_paths, hue_bins=8, sat_bins=8, val_bins=8)
df.head()
# Out:
#                                          image_paths      Hue0      Hue1  \
# 0  examples/Rothko_images/AMICO_BOSTON_103832163.jpg  0.013589  0.010285
# 1      examples/Rothko_images/AMICO_CL_103800789.jpg  0.000000  0.125000
# 2  examples/Rothko_images/AMICO_DALLAS_103842196.jpg  0.038496  0.034686
# 3  examples/Rothko_images/AMICO_DALLAS_103842510.jpg  0.497106  0.159147
# 4  examples/Rothko_images/AMICO_DALLAS_103842720.jpg  0.000000  0.000000
#
#        Hue2      Hue3      Hue4      Hue5      Hue6      Hue7      Sat0  \
# 0  0.022245  0.058405  0.104384  0.178518  0.303518  0.309010  0.004565
# 1  0.125000  0.000000  0.125000  0.000000  0.000000  0.500000  0.000000
# 2  0.077922  0.146585  0.178480  0.168335  0.180695  0.174759  0.195335
# 3  0.125417  0.085687  0.057027  0.035632  0.022832  0.017137  0.055556
# 4  0.000000  0.000000  0.000000  0.000000  0.500000  0.000000  0.000000
#
#      ...         Sat6      Sat7      Val0      Val1      Val2      Val3  \
# ...
